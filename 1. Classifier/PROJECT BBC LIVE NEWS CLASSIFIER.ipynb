# %% [markdown]
# ## Preprocessing with scikit learn

# %%
import os
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Import the BBC news dataset

# %%
# %run '/home/nbuser/library/1. Classifier/1. BBC news files/Import and read text.ipynb'
# Out:
# UsageError: Line magic function `%` not found.

# %% [markdown]
# #### Clean and pre-process data

# %%
# %run  '/home/nbuser/library/1. Classifier/3. Exploratory Data Analysis/Cleaning and explore data.ipynb'
# Out:
# ERROR:root:File `"'/home/nbuser/library/1..py"` not found.

# %% [markdown]
# #### Import Live BBC News

# %%
% run  '/home/nbuser/library/2. News Scrapper/BBC news scrapper with NewsApi.ipynb'
# Out:
# ...
#      |████████████████████████████████| 61kB 1.3MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 102kB 6.9MB/s ta 0:00:011
# ...
#      |████████████████████████████████| 1.2MB 6.7MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.1MB 30.4MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 194kB 5.1MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.8MB 4.9MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 327kB 4.6MB/s eta 0:00:01
# ...
#   Using cached https://files.pythonhosted.org/packages/1d/e7/fd8b501e7a6dfe492a433deb7b9d833d39ca74916fa8bc63dd1a4947a671/Jinja2-2.10.1-py2.py3-none-any.whl
# ...
#   Created wheel for dash: filename=dash-1.3.1-cp35-none-any.whl size=67781 sha256=f3b60e003d7fb5571649be0d1d7ce818c86e08f94769ada3410ae785dde0d7a0
#   Stored in directory: /home/nbuser/.cache/pip/wheels/49/33/11/497991979e5a8e4a2ac31072d7674dd402e67035689ef9eb45
# ...

# %% [markdown]
# #### Train and test data

# %%
% run '/home/nbuser/library/1. Classifier/4. Feature Engineering/Pre-processing, feature engineering CV TF-IDF and modeling with scikit learn 0.988 accuracy!.ipynb'

# %% [markdown]
# #### Import classified news DataFrame

# %%
BBC_NEWS_CLASS_DF = pd.read_csv('/home/nbuser/library/2. News Scrapper/BBC_LIVE_NEWS_CLASSES.csv')

# %%
BBC_NEWS_CLASS_DF
# Out:
#                Date/Time                                          news_text  \
# 0   2019-09-24T04:06:52Z    Brook House immigration removal centre near ...
# 1   2019-09-24T03:26:09Z   AFP  Emmanuel Macron l met Angela Merkel and ...
# 2   2019-09-24T03:20:12Z   Nazanin ZaghariRatcliffe   Nazanin ZaghariRat...
# 3   2019-09-24T03:10:16Z      People were trapped in burning buildings i...
# 4   2019-09-24T01:36:50Z                                                NaN
# 5   2019-09-24T01:27:11Z   ReutersThomas Cook customers have accused air...
# 6   2019-09-24T00:30:59Z  Media captionThe move has been called fundamen...
# 7   2019-09-24T00:18:02Z      Playing music to dementia patients reduced...
# 8   2019-09-24T00:16:55Z      Pupils studying for Nat4s 5s and Highers c...
# 9   2019-09-24T00:13:32Z    Sheerans design seen in detail on the right ...
# 10  2019-09-24T00:11:47Z    ImagesObesity is not a choice and making peo...
# ...

# %% [markdown]
# ### TA-DAAAA!
